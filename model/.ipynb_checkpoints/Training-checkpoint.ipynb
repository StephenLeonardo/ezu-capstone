# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, LeakyReLU, MaxPooling2D, Dropout, concatenate, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend
import tensorflow as tf

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
path_save_spectrogram = 'C:/Users/Steph/#Binus/#Bangkit/#Project/Code/Audio Dataset/CombinedData/Train/spectrogram/'

X_in = np.load(path_save_spectrogram +'noisy_voice_amp_db'+".npy")
X_ou = np.load(path_save_spectrogram +'voice_amp_db'+".npy")

# %%
plt.imshow(X_in[0], cmap='gray')
X_in.shape
# Out:
# (50, 128, 128)

# %%
plt.imshow(X_ou[0], cmap='gray')
X_ou.shape
# Out:
# (50, 128, 128)

# %%
X_ou = X_in - X_ou
plt.imshow(X_ou[0], cmap='gray')
X_ou.shape
# Out:
# (50, 128, 128)

# %%
def scaled_in(matrix_spec):
    "global scaling apply to noisy voice spectrograms (scale between -1 and 1)"
    matrix_spec = (matrix_spec + 46)/50
    return matrix_spec

def scaled_ou(matrix_spec):
    "global scaling apply to noise models spectrograms (scale between -1 and 1)"
    matrix_spec = (matrix_spec -6 )/82
    return matrix_spec

# %%
X_in = scaled_in(X_in)
X_ou = scaled_ou(X_ou)

# %%
X_in = X_in.reshape(X_in.shape[0],X_in.shape[1],X_in.shape[2],1)
X_ou = X_ou.reshape(X_ou.shape[0],X_ou.shape[1],X_ou.shape[2],1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_in, X_ou, test_size=0.1, random_state=322)

# %%
#Unet network
def unet(pretrained_weights = None,input_size = (128,128,1)):
    #size filter input
    size_filter_in = 16
    #normal initialization of weights
    kernel_init = 'he_normal'
    #To apply leaky relu after the conv layer 
    activation_layer = None
    inputs = Input(input_size)
    conv1 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(inputs)
    conv1 = LeakyReLU()(conv1)
    conv1 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv1)
    conv1 = LeakyReLU()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool1)
    conv2 = LeakyReLU()(conv2)
    conv2 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv2)
    conv2 = LeakyReLU()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool2)
    conv3 = LeakyReLU()(conv3)
    conv3 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv3)
    conv3 = LeakyReLU()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool3)
    conv4 = LeakyReLU()(conv4)
    conv4 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv4)
    conv4 = LeakyReLU()(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(size_filter_in*16, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool4)
    conv5 = LeakyReLU()(conv5)
    conv5 = Conv2D(size_filter_in*16, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv5)
    conv5 = LeakyReLU()(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(size_filter_in*8, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(drop5))
    up6 = LeakyReLU()(up6)
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge6)
    conv6 = LeakyReLU()(conv6)
    conv6 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv6)
    conv6 = LeakyReLU()(conv6)
    up7 = Conv2D(size_filter_in*4, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(conv6))
    up7 = LeakyReLU()(up7)
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge7)
    conv7 = LeakyReLU()(conv7)
    conv7 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv7)
    conv7 = LeakyReLU()(conv7)
    up8 = Conv2D(size_filter_in*2, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(conv7))
    up8 = LeakyReLU()(up8)
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge8)
    conv8 = LeakyReLU()(conv8)
    conv8 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv8)
    conv8 = LeakyReLU()(conv8)

    up9 = Conv2D(size_filter_in, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(conv8))
    up9 = LeakyReLU()(up9)
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge9)
    conv9 = LeakyReLU()(conv9)
    conv9 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv9)
    conv9 = LeakyReLU()(conv9)
    conv9 = Conv2D(2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv9)
    conv9 = LeakyReLU()(conv9)
    conv10 = Conv2D(1, 1, activation = 'tanh')(conv9)

    model = Model(inputs,conv10)

    model.compile(optimizer = 'adam', loss = tf.keras.losses.Huber(), metrics = ['mae'])

    #model.summary()

    if(pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
model=unet()

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 160         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 128, 128, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 16) 2320        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 128, 128, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 16)   0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 32)   9248        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 64)   36928       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 32, 32, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  147584      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 128)  0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 256)    295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 8, 8, 256)    590080      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 8, 8, 256)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 256)    0           leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 256)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  131200      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16, 16, 256)  0           dropout[0][0]
#                                                                  leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0           leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   32832       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 128)  0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)   0           leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   8224        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 64)   0           leaky_re_lu_3[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32) 0           leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 16) 2064        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 32) 0           leaky_re_lu_1[0][0]
#                                                                  leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 2)  290         leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 128, 128, 2)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 1)  3           leaky_re_lu_22[0][0]
# ==================================================================================================
# Total params: 1,941,093
# Trainable params: 1,941,093
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
X_train.shape
# Out:
# (45, 128, 128, 1)

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=5, shuffle=True, verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 9/9 [==============================] - 2s 173ms/step - loss: 0.0650 - mae: 0.2583 - val_loss: 0.0180 - val_mae: 0.1663
# Epoch 2/50
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0133 - mae: 0.1280 - val_loss: 0.0096 - val_mae: 0.1109
# Epoch 3/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0106 - mae: 0.1150 - val_loss: 0.0135 - val_mae: 0.1402
# Epoch 4/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0116 - mae: 0.1159 - val_loss: 0.0099 - val_mae: 0.1178
# Epoch 5/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0120 - mae: 0.1144 - val_loss: 0.0089 - val_mae: 0.0970
# Epoch 6/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0112 - mae: 0.1137 - val_loss: 0.0102 - val_mae: 0.1012
# Epoch 7/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0116 - mae: 0.1179 - val_loss: 0.0355 - val_mae: 0.2305
# Epoch 8/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0107 - mae: 0.1189 - val_loss: 0.0151 - val_mae: 0.1513
# Epoch 9/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0098 - mae: 0.1090 - val_loss: 0.0099 - val_mae: 0.1078
# Epoch 10/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0091 - mae: 0.1046 - val_loss: 0.0102 - val_mae: 0.1033
# Epoch 11/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0088 - mae: 0.1009 - val_loss: 0.0102 - val_mae: 0.0989
# Epoch 12/50
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0088 - mae: 0.0989 - val_loss: 0.0103 - val_mae: 0.0996
# Epoch 13/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0093 - mae: 0.1024 - val_loss: 0.0097 - val_mae: 0.0998
# Epoch 14/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0092 - mae: 0.1001 - val_loss: 0.0100 - val_mae: 0.0993
# Epoch 15/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0093 - mae: 0.1041 - val_loss: 0.0072 - val_mae: 0.0974
# Epoch 16/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0082 - mae: 0.0970 - val_loss: 0.0065 - val_mae: 0.0852
# Epoch 17/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0083 - mae: 0.1001 - val_loss: 0.0092 - val_mae: 0.1023
# Epoch 18/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0079 - mae: 0.0946 - val_loss: 0.0098 - val_mae: 0.0938
# Epoch 19/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0081 - mae: 0.0934 - val_loss: 0.0105 - val_mae: 0.0959
# Epoch 20/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0074 - mae: 0.0917 - val_loss: 0.0105 - val_mae: 0.0953
# Epoch 21/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0077 - mae: 0.0929 - val_loss: 0.0085 - val_mae: 0.0884
# Epoch 22/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0084 - mae: 0.0969 - val_loss: 0.0086 - val_mae: 0.0904
# Epoch 23/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0087 - mae: 0.0974 - val_loss: 0.0085 - val_mae: 0.0991
# Epoch 24/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0083 - mae: 0.0991 - val_loss: 0.0109 - val_mae: 0.1005
# Epoch 25/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0075 - mae: 0.0901 - val_loss: 0.0116 - val_mae: 0.0987
# Epoch 26/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0073 - mae: 0.0903 - val_loss: 0.0119 - val_mae: 0.0981
# Epoch 27/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0073 - mae: 0.0883 - val_loss: 0.0105 - val_mae: 0.0972
# Epoch 28/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0071 - mae: 0.0894 - val_loss: 0.0106 - val_mae: 0.0928
# Epoch 29/50
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0073 - mae: 0.0883 - val_loss: 0.0109 - val_mae: 0.0965
# Epoch 30/50
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0070 - mae: 0.0891 - val_loss: 0.0103 - val_mae: 0.0937
# Epoch 31/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0067 - mae: 0.0856 - val_loss: 0.0100 - val_mae: 0.0957
# Epoch 32/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0065 - mae: 0.0857 - val_loss: 0.0095 - val_mae: 0.0885
# Epoch 33/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0065 - mae: 0.0823 - val_loss: 0.0109 - val_mae: 0.0975
# Epoch 34/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0068 - mae: 0.0855 - val_loss: 0.0097 - val_mae: 0.0919
# Epoch 35/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0062 - mae: 0.0834 - val_loss: 0.0123 - val_mae: 0.0973
# Epoch 36/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0064 - mae: 0.0822 - val_loss: 0.0111 - val_mae: 0.0942
# Epoch 37/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0063 - mae: 0.0827 - val_loss: 0.0075 - val_mae: 0.0817
# Epoch 38/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0059 - mae: 0.0795 - val_loss: 0.0054 - val_mae: 0.0752
# Epoch 39/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0058 - mae: 0.0786 - val_loss: 0.0052 - val_mae: 0.0676
# Epoch 40/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0057 - mae: 0.0785 - val_loss: 0.0052 - val_mae: 0.0691
# Epoch 41/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0055 - mae: 0.0760 - val_loss: 0.0067 - val_mae: 0.0748
# Epoch 42/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0055 - mae: 0.0755 - val_loss: 0.0083 - val_mae: 0.0825
# Epoch 43/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0061 - mae: 0.0796 - val_loss: 0.0049 - val_mae: 0.0681
# Epoch 44/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0057 - mae: 0.0770 - val_loss: 0.0082 - val_mae: 0.0851
# Epoch 45/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0056 - mae: 0.0783 - val_loss: 0.0095 - val_mae: 0.0853
# Epoch 46/50
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0054 - mae: 0.0748 - val_loss: 0.0064 - val_mae: 0.0734
# Epoch 47/50
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0053 - mae: 0.0747 - val_loss: 0.0104 - val_mae: 0.0908
# Epoch 48/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0054 - mae: 0.0755 - val_loss: 0.0090 - val_mae: 0.0834
# Epoch 49/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0055 - mae: 0.0765 - val_loss: 0.0093 - val_mae: 0.0863
# Epoch 50/50
# 9/9 [==============================] - 0s 36ms/step - loss: 0.0051 - mae: 0.0728 - val_loss: 0.0067 - val_mae: 0.0739

# %%
model.save('my_model3')
# Out:
# WARNING:tensorflow:From C:\Users\Steph\Anaconda3\envs\coursera\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: my_model3\assets

# %%
plt.imshow(X_train[0], cmap='gray')

# %%
asd = model.predict(np.array([X_train[0]]))

# %%
X_train[0].shape
# Out:
# (128, 128, 1)

# %%
plt.imshow(asd[0], cmap='gray')

# %%
plt.imshow(y_train[0], cmap='gray')
